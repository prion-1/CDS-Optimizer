# %% [markdown]
# # mRNA Expression Optimization Tool
#
# This notebook optimizes a protein-coding nucleic acid sequence for host-specific enhanced expression and facilitated cloning/synthesis.

# %% [markdown]
# ## 1. Setup and Initialization

# %%
# Basic imports
import os
import sys
import re

# Import project modules
from src.optimization import genetic_algorithm, FitnessWeights
from src.pre_optimization import optimize_codons
from src.local_repair import local_repair
from src.utils import (
    translate_dna_to_protein, back_translate_protein,
    calculate_gc_content, calculate_cai, load_codon_table,
    list_available_hosts, is_eukaryote_host, get_target_gc,
    harmonization_correlation, tai_available_for,
    codon_pair_available_for, calculate_codon_pair_score, calculate_tai,
)
from src.gceh_module import (
    gceh_anal,
    plot_codon_usage_compare,
    plot_complexity_compare,
    plot_gc3_compare,
    plot_gc3_sliding_compare,
    plot_gc_sliding_compare
)

# Import widgets
from ipywidgets import (
    Text, Textarea, Button, FloatSlider, IntSlider, Dropdown, 
    VBox, HBox, Label, HTML, Output, Layout, Tab, Accordion,
    FloatProgress, IntProgress, IntText, Checkbox, BoundedIntText
)
from IPython.display import display, clear_output

# Import plotting libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Discover available hosts dynamically from data/codon_tables/.
# Drop a new <host>.csv into that folder to make it appear here.
host_options = list_available_hosts()

# %% [markdown]
# ## 2. Helper Functions

# %%
def validate_protein_sequence(sequence):
    '''Validate protein sequence and return cleaned version or error.'''
    # Remove spaces and line breaks
    sequence = re.sub(r'\s+', '', sequence.upper())
    
    if not sequence:
        return None, 'Sequence is empty'
    
    # Valid amino acids
    valid_aas = set('ACDEFGHIKLMNPQRSTVWY')
    
    # Check for invalid characters
    invalid_chars = set(sequence) - valid_aas
    if invalid_chars:
        return None, f'Invalid amino acids: {', '.join(invalid_chars)}'
    
    return sequence, None


def clean_nucleotide_sequence(sequence):
    '''Clean and validate nucleotide sequence.'''
    # Remove spaces, line breaks, and numbers
    sequence = re.sub(r'[\s\d]+', '', sequence.upper())
    
    if not sequence:
        return None, 'Sequence is empty'
    elif len(sequence) < 9:
        return None, 'What are you trying to optimize, you great optimizer?'
    
    # Check for invalid characters
    valid_nucs = set('ATGC')
    invalid_chars = set(sequence) - valid_nucs
    if invalid_chars:
        if invalid_chars == {'U'}:
            sequence = sequence.replace('U', 'T')
        else:
            invalid_chars.discard('U')
            return None, f'Invalid nucleotides: {', '.join(invalid_chars)}'
    
    # Truncate to satisfy frame
    if len(sequence) % 3 != 0:
        rest = len(sequence) % 3
        sequence = sequence[:-rest]
        print(f'Disrupted sequence frame! Truncating last {rest} nucleotides.\n')
    
    # Find and truncate at first stop codon
    stop_codons = ['TAA', 'TAG', 'TGA']
    for i in range(0, len(sequence) - 2, 3):
        codon = sequence[i:i+3]
        if codon in stop_codons:
            is_terminal = (i+3 == len(sequence))    # sequence % 3 already 0 at this point
            trash = len(sequence[i+3:]) / len(sequence) * 100
            sequence = sequence[:i+3]            
            if is_terminal:
                print(f'Terminal stop codon found at position {i+1}.\n')
            else:
                print(f'Non-terminal stop codon found at position {i+1}! Discarding last {trash:.0f}%.\n')
            break
    
    return sequence, None

# %% [markdown]
# ## 3. Create Interactive GUI

# %%
# Global variables for widgets
global weight_sliders, weight_labels, sum_label, optimize_button, progress_bar

# Default weight values
DEFAULT_WEIGHTS = {
    'cai': 0.40,
    'gc': 0.20,
    'folding': 0.15,
    'motifs': 0.10,
    'repeats': 0.07,
    'splice': 0.08,
    'cps': 0.00,
    'tai': 0.00,
}

# ---- Protein input ----
protein_input = Textarea(
    value = '',
    placeholder = 'Enter AA sequence (single letter code)\n',
    disabled = False,
    layout = Layout(width = '600px', height = '80px')
)

backtranslate_button = Button(
    description = 'Back-translate to DNA',
    button_style = 'primary',
    tooltip = 'Convert protein to DNA sequence',
    layout = Layout(width = '200px')
)

protein_status = HTML(value = '<i>No protein specified</i>')

# ---- DNA input ----
dna_input = Textarea(
    value = '',
    placeholder = 'Enter DNA/RNA sequence\n',
    disabled = False,
    layout = Layout(width = '600px', height = '100px')
)

dna_status = HTML(value = '<i>DNA sequence will appear here after back-translation or direct input</i>')

# ---- Host organism selection ----
host_dropdown = Dropdown(
    options = host_options,
    disabled = False,
    layout = Layout(width = '300px')
)
host_class = HTML(value = '<i>Host class:</i>')
if 'hsapiens' in host_options:
    host_dropdown.value = 'hsapiens'
    host_class.value = 'Eukaryote'

# ---- Codon optimization method ----
codon_method_dropdown = Dropdown(
    options = [
        ('Maximum CAI', 'simple'),
        ('Percentile-matched harmonization', 'percentile'),
        ('Structure-aware heuristic (CAI + 5\' MFE beam search)', 'structure'),
    ],
    value = 'percentile',
    disabled = False,
    layout = Layout(width = '450px')
)

# Percentile matching sub-options
percentile_mode_dropdown = Dropdown(
    options = [
        ('Simple percentile matching (source host-agnostic)', 'simple'),
        ('Source host-informed percentile matching', 'source_informed'),
    ],
    value = 'simple',
    disabled = False,
    layout = Layout(width = '450px')
)

source_host_label = HTML(
    value = '<b>Source organism:</b>',
    layout = Layout(display = 'none')
)

source_host_dropdown = Dropdown(
    options = host_options,
    disabled = False,
    layout = Layout(width = '300px', display = 'none')
)

# ---- Pipeline selector ----
pipeline_dropdown = Dropdown(
    options = [
        ('Preoptimization only', 'preoptimization_only'),
        ('Preoptimization + Genetic Algorithm', 'preoptimization_ga'),
        ('Hybrid: Preoptimization + Local Repair (+ optional GA polish)', 'hybrid'),
    ],
    value = 'preoptimization_ga',
    disabled = False,
    layout = Layout(width = '500px')
)

# ---- Avoid sequences ----
avoid_input = Text(
    value = '',
    placeholder = 'Sequences to avoid (comma-separated, AGCT only)',
    layout = Layout(width = '400px')
)

# ---- GA parameters ----
pop_size_slider = IntSlider(
    value = 20, min = 10, max = 200, step = 10,
    description = 'Population:', layout = Layout(width = '400px')
)

generations_slider = IntSlider(
    value = 25, min = 25, max = 300, step = 25,
    description = 'Generations:', layout = Layout(width = '400px')
)

mutation_slider = FloatSlider(
    value = 0.035, min = 0.005, max = 0.1, step = 0.005,
    description = 'Mutation:', readout_format = '.3f',
    layout = Layout(width = '400px')
)

# ---- Local repair parameters ----
repair_window_slider = IntSlider(
    value = 42, min = 15, max = 90, step = 3,
    description = 'Window (nt):',
    layout = Layout(width = '400px')
)

repair_max_subs = IntSlider(
    value = 2, min = 1, max = 5, step = 1,
    description = 'Max subs/win:',
    layout = Layout(width = '400px')
)

# ---- GA polish parameters (hybrid pipeline) ----
ga_polish_checkbox = Checkbox(
    value = False,
    description = 'Enable light GA polish',
    layout = Layout(width = '250px')
)

polish_generations_slider = IntSlider(
    value = 15, min = 5, max = 50, step = 5,
    description = 'Generations:',
    layout = Layout(width = '400px', display = 'none')
)

polish_mutation_slider = FloatSlider(
    value = 0.008, min = 0.002, max = 0.02, step = 0.002,
    description = 'Mutation:',
    readout_format = '.3f',
    layout = Layout(width = '400px', display = 'none')
)

# ---- Complexity track parameters ----
complexity_window = BoundedIntText(
    value = 50, min = 1, max = 1000000,
    description = 'Window:', layout = Layout(width = '200px')
)

complexity_step = BoundedIntText(
    value = 5, min = 1, max = 1000000,
    description = 'Step:', layout = Layout(width = '200px')
)

complexity_k = BoundedIntText(
    value = 3, min = 1, max = 10,
    description = 'k-mer k:', layout = Layout(width = '200px')
)

complexity_smooth = BoundedIntText(
    value = 4, min = 0, max = 49,
    description = 'Smooth:', layout = Layout(width = '200px')
)

complexity_alpha = FloatSlider(
    value = 0.5, min = 0.0, max = 2.0, step = 0.05,
    description = 'GC alpha:', readout_format = '.2f',
    orientation = 'horizontal',
)

# ---- Fitness weight sliders ----
weights_label = HTML(value = '<b>Fitness Function Weights:</b> (must sum to 1.0)')

weight_sliders = {
    'cai': FloatSlider(value = DEFAULT_WEIGHTS['cai'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
    'gc': FloatSlider(value = DEFAULT_WEIGHTS['gc'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
    'folding': FloatSlider(value = DEFAULT_WEIGHTS['folding'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
    'motifs': FloatSlider(value = DEFAULT_WEIGHTS['motifs'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
    'repeats': FloatSlider(value = DEFAULT_WEIGHTS['repeats'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
    'splice': FloatSlider(value = DEFAULT_WEIGHTS['splice'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
    'cps': FloatSlider(value = DEFAULT_WEIGHTS['cps'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
    'tai': FloatSlider(value = DEFAULT_WEIGHTS['tai'], min = 0, max = 1, step = 0.01, description = '', readout_format = '.2f', layout = Layout(width = '300px')),
}

weight_label_names = {
    'cai': 'CAI:', 'gc': 'GC Content:', 'folding': 'Folding:',
    'motifs': 'Motifs:', 'repeats': 'Repeats:', 'splice': 'Splice Sites:',
    'cps': 'Codon-pair bias:', 'tai': 'tAI (opt-in):'
}

weight_labels = {
    key: HTML(value = f'<span style = "color: green; width: 120px; display: inline-block;"><b>{weight_label_names[key]}</b></span>')
    for key in weight_sliders.keys()
}

weight_rows = {
    key: HBox([weight_labels[key], weight_sliders[key]])
    for key in weight_sliders.keys()
}

sum_label = HTML(value = '<span style = "color: green;"><b>Total: 1.00</b></span>')

reset_button = Button(
    description = 'Reset Weights', button_style = 'warning',
    tooltip = 'Reset weights to default values', icon = 'refresh',
    layout = Layout(width = '150px')
)

# ---- Optimize button, progress, output ----
optimize_button = Button(
    description = 'Optimize Sequence', button_style = 'success',
    disabled = False, layout = Layout(width = '200px', height = '40px')
)

progress_bar = IntProgress(
    value = 0, min = 0, max = 100, description = 'Progress:',
    bar_style = 'info', orientation = 'horizontal',
    layout = Layout(width = '600px', display = 'none')
)

progress_label = HTML(value = '', layout = Layout(display = 'none'))

output_area = Output(layout = Layout(width = '100%', border = '1px solid #ddd', padding = '10px'))

# ---- Container boxes for conditional visibility ----
# (all individual widgets defined above, safe to reference)

ga_settings_box = VBox([
    HTML('<h4>Genetic Algorithm Settings:</h4>'),
    pop_size_slider,
    generations_slider,
    mutation_slider,
])

repair_settings_box = VBox([
    HTML('<h4>Local Repair Settings:</h4>'),
    repair_window_slider,
    repair_max_subs,
    HTML('<h4>Optional GA Polish:</h4>'),
    ga_polish_checkbox,
    polish_generations_slider,
    polish_mutation_slider,
], layout = Layout(display = 'none'))

avoid_section = VBox([
    HTML('<b>Avoid sequences (optional):</b>'),
    avoid_input,
])

weights_section = VBox([
    weights_label,
    VBox([
        weight_rows['cai'],
        weight_rows['gc'],
        weight_rows['folding'],
        weight_rows['motifs'],
        weight_rows['repeats'],
        weight_rows['splice'],
        weight_rows['cps'],
        weight_rows['tai'],
    ]),
    VBox([sum_label, reset_button]),
])

# %% [markdown]
# ## 4. Event Handlers

# %%
def update_weight_labels():
    '''Update weight label colors based on sum.'''
    total = sum(weight_sliders[key].value for key in weight_sliders)
    is_valid = abs(total - 1.0) < 0.01

    # Weights only matter when GA is running
    weights_needed = (
        pipeline_dropdown.value == 'preoptimization_ga' or
        (pipeline_dropdown.value == 'hybrid' and ga_polish_checkbox.value)
    )
    if not weights_needed:
        is_valid = True

    color = 'green' if is_valid else 'red'
    for key, label in weight_labels.items():
        label.value = f'<span style = "color: {color}; width: 120px; display: inline-block;"><b>{weight_label_names[key]}</b></span>'

    sum_label.value = f'<span style = "color: {color};"><b>Total: {total:.2f}</b></span>'

    optimize_button.disabled = not is_valid
    optimize_button.button_style = 'success' if is_valid else 'danger'
    optimize_button.description = 'Optimize Sequence' if is_valid else 'Fix Weights First'


def update_optional_weight_controls():
    '''Show optional weight controls only when backing data is available.'''
    host = host_dropdown.value
    optional_available = {
        'cps': codon_pair_available_for(host),
        'tai': tai_available_for(host),
    }
    for key, available in optional_available.items():
        weight_rows[key].layout.display = 'flex' if available else 'none'
        if not available:
            weight_sliders[key].value = 0.0

def on_backtranslate_click(b):
    '''Handle back-translation button click.'''
    clean_protein, error = validate_protein_sequence(protein_input.value)

    if error:
        protein_status.value = f'<span style = "color: red;">Error: {error}</span>'
        return

    try:
        dna_seq = back_translate_protein(clean_protein, host_dropdown.value)
        dna_input.value = dna_seq
        protein_status.value = f'<span style = "color: green;">Protein: {len(clean_protein)} aa</span>'
        dna_status.value = f'<span style = "color: green;">DNA: {len(dna_seq)} bp ({len(dna_seq)//3} codons)</span>'
    except Exception as e:
        protein_status.value = f'<span style = "color: red;">Error: {str(e)}</span>'

def on_weight_change(change):
    '''Handle weight slider changes.'''
    if change['type'] == 'change' and change['name'] == 'value':
        update_weight_labels()

def on_host_change(change):
    '''Set eukaryote flag based on host selection (uses utils registry).'''
    kind = is_eukaryote_host(change['new'])
    if kind is True:
        host_class.value = 'Eukaryote'
    elif kind is False:
        host_class.value = 'Prokaryote'
    else:
        host_class.value = '<i>Unknown — add to HOST_KINGDOM in utils.py</i>'

    update_optional_weight_controls()
    update_weight_labels()

def on_codon_method_change(change):
    '''Show/hide percentile matching options based on selected method.'''
    if change['new'] == 'percentile':
        percentile_mode_dropdown.layout.display = 'flex'
        if percentile_mode_dropdown.value == 'source_informed':
            source_host_label.layout.display = 'block'
            source_host_dropdown.layout.display = 'flex'
    else:
        percentile_mode_dropdown.layout.display = 'none'
        source_host_label.layout.display = 'none'
        source_host_dropdown.layout.display = 'none'

def on_percentile_mode_change(change):
    '''Show/hide source host dropdown based on percentile mode.'''
    if change['new'] == 'source_informed':
        source_host_label.layout.display = 'block'
        source_host_dropdown.layout.display = 'flex'
    else:
        source_host_label.layout.display = 'none'
        source_host_dropdown.layout.display = 'none'

def on_pipeline_change(change):
    '''Show/hide parameter groups based on selected pipeline.'''
    pipeline = change['new']

    if pipeline == 'preoptimization_only':
        ga_settings_box.layout.display = 'none'
        repair_settings_box.layout.display = 'none'
        weights_section.layout.display = 'none'
        avoid_section.layout.display = 'none'
    elif pipeline == 'preoptimization_ga':
        ga_settings_box.layout.display = 'block'
        repair_settings_box.layout.display = 'none'
        weights_section.layout.display = 'block'
        avoid_section.layout.display = 'block'
    elif pipeline == 'hybrid':
        ga_settings_box.layout.display = 'none'
        repair_settings_box.layout.display = 'block'
        weights_section.layout.display = 'block' if ga_polish_checkbox.value else 'none'
        avoid_section.layout.display = 'block'

    update_weight_labels()

def on_ga_polish_change(change):
    '''Show/hide GA polish sliders and weights section.'''
    if change['new']:
        polish_generations_slider.layout.display = 'flex'
        polish_mutation_slider.layout.display = 'flex'
        weights_section.layout.display = 'block'
    else:
        polish_generations_slider.layout.display = 'none'
        polish_mutation_slider.layout.display = 'none'
        if pipeline_dropdown.value == 'hybrid':
            weights_section.layout.display = 'none'

    update_weight_labels()

def on_reset_click(b):
    '''Reset weights to default values.'''
    for key, slider in weight_sliders.items():
        slider.value = DEFAULT_WEIGHTS[key]
    update_weight_labels()

def update_progress(current, total):
    '''Update progress bar during optimization.'''
    progress = int((current / total) * 100)
    progress_bar.value = progress
    progress_label.value = f'<i>Generation {current}/{total}</i>'

def on_optimize_click(b):
    '''Handle optimize button click — routes through selected pipeline.'''
    with output_area:
        clear_output(wait = True)

        clean_seq, error = clean_nucleotide_sequence(dna_input.value)
        if error:
            print(f'Error: {error}')
            return

        # Common setup
        pipeline = pipeline_dropdown.value
        host = host_dropdown.value
        method = codon_method_dropdown.value

        kind = is_eukaryote_host(host)
        if kind is None:
            raise ValueError(
                f'Host {host!r} is not classified as eukaryote or prokaryote. '
                'Add it to HOST_KINGDOM in src/utils.py.'
            )
        is_eukaryote = kind

        source_host = None
        if method == 'percentile' and percentile_mode_dropdown.value == 'source_informed':
            source_host = source_host_dropdown.value

        # Header
        print('=' * 70)
        print('OPTIMIZATION STARTED')
        print('=' * 70)
        print(f'Pipeline: {pipeline_dropdown.label}')
        print(f'Host: {host}')
        print(f'Method: {codon_method_dropdown.label}')
        if method == 'percentile':
            print(f'Percentile mode: {percentile_mode_dropdown.label}')
            if source_host:
                print(f'Source organism: {source_host}')
        print(f'Input sequence: {len(clean_seq)} bp')
        if clean_seq[-3:] in ['TAA', 'TAG', 'TGA']:
            print(f'Protein: {(len(clean_seq) - 3) / 3:.0f} aa')
        else:
            print(f'Protein: {len(clean_seq) / 3:.0f} aa')

        # ---- Preoptimization (all pipelines) ----
        print('\n' + '=' * 70)
        if pipeline == 'preoptimization_only':
            print('PREOPTIMIZATION: Optimization complete')
        else:
            print('PREOPTIMIZATION')
        print('=' * 70)

        try:
            pre_optimized = optimize_codons(clean_seq, host, is_eukaryote, method, source_host)
            print(f'Method: {codon_method_dropdown.label}')
            sequence_label = 'Optimized sequence' if pipeline == 'preoptimization_only' else 'Preoptimization sequence'
            print(f'{sequence_label} ({len(pre_optimized)} bp):')
            display(Textarea(value = pre_optimized, layout = Layout(width = '600px', height = '400px')))

            codon_table = load_codon_table(host)
            pre_cai = calculate_cai(pre_optimized, codon_table)
            pre_gc = calculate_gc_content(pre_optimized)
            if pipeline != 'preoptimization_only':
                print(f'Preoptimization CAI: {pre_cai:.3f}')
                print(f'Preoptimization GC: {pre_gc:.1f}%')
        except Exception as e:
            print(f'\nPreoptimization failed: {str(e)}')
            return

        final_seq = pre_optimized  # default for preoptimization-only

        # ---- Genetic Algorithm ----
        if pipeline == 'preoptimization_ga':
            print('\n' + '=' * 70)
            print('GENETIC ALGORITHM')
            print('=' * 70)
            print(f'Population: {pop_size_slider.value}, Generations: {generations_slider.value}')
            print('Optimizing...\n')

            progress_bar.layout.display = 'flex'
            progress_label.layout.display = 'block'
            progress_bar.value = 0

            weights = {
                'cai': weight_sliders['cai'].value,
                'gc_deviation': weight_sliders['gc'].value,
                'folding_energy': weight_sliders['folding'].value,
                'unwanted_motifs': weight_sliders['motifs'].value,
                'repeats': weight_sliders['repeats'].value,
                'cryptic_splice': weight_sliders['splice'].value,
                'codon_pair_bias': weight_sliders['cps'].value,
                'tai': weight_sliders['tai'].value,
            }

            try:
                optimized_seq, fitness, metrics = genetic_algorithm(
                    initial_cds = pre_optimized,
                    host = host,
                    is_eukaryote = is_eukaryote,
                    target_gc = get_target_gc(host),
                    pop_size = pop_size_slider.value,
                    generations = generations_slider.value,
                    mutation_rate = mutation_slider.value,
                    weights = weights,
                    avoid_sequences = avoid_input.value,
                    verbose = True,
                    progress_callback = lambda g, t: update_progress(g, t),
                )

                progress_bar.layout.display = 'none'
                progress_label.layout.display = 'none'
                final_seq = optimized_seq

                print(f'\nGA Fitness: {fitness:.4f}')
                print(f'CAI: {metrics["cai"]:.3f}')
                print(f'GC: {metrics["gc_content"]:.1f}%')
                if codon_pair_available_for(host):
                    print(f'Codon-pair score: {metrics["codon_pair_score"]:.3f}')
                if tai_available_for(host):
                    print(f'tAI: {metrics["tai"]:.3f}')

            except Exception as e:
                progress_bar.layout.display = 'none'
                progress_label.layout.display = 'none'
                print(f'\nGA optimization failed: {str(e)}')
                return

        # ---- Hybrid: Local Repair + optional GA Polish ----
        elif pipeline == 'hybrid':
            print('\n' + '=' * 70)
            print('LOCAL REPAIR')
            print('=' * 70)

            avoid_motifs = (
                [s.strip().upper() for s in avoid_input.value.split(',') if s.strip()]
                if avoid_input.value else None
            )

            try:
                repaired, changelog = local_repair(
                    sequence = pre_optimized,
                    host = host,
                    is_eukaryote = is_eukaryote,
                    preoptimization_sequence = pre_optimized,
                    target_gc = get_target_gc(host),
                    window_nt = repair_window_slider.value,
                    max_subs_per_window = repair_max_subs.value,
                    motifs = avoid_motifs,
                )

                if changelog:
                    print(f'\n{len(changelog)} codon(s) repaired:\n')
                    print(f'{"Pos":>5}  {"nt":>5}  {"Old":>5}  {"New":>5}  {"AA":>3}  {"Reason"}')
                    print('-' * 48)
                    for entry in changelog:
                        print(f'{entry["position"]:>5}  {entry["nt_position"]:>5}  '
                              f'{entry["old_codon"]:>5}  {entry["new_codon"]:>5}  '
                              f'{entry["amino_acid"]:>3}  {entry["reason"]}')
                else:
                    print('\nNo repairs needed.')

                rep_cai = calculate_cai(repaired, codon_table)
                rep_gc = calculate_gc_content(repaired)
                print(f'\nRepaired CAI: {rep_cai:.3f}')
                print(f'Repaired GC: {rep_gc:.1f}%')

                final_seq = repaired

            except Exception as e:
                print(f'\nLocal repair failed: {str(e)}')
                return

            # Optional GA polish
            if ga_polish_checkbox.value:
                print('\n' + '=' * 70)
                print('GA POLISH')
                print('=' * 70)
                print(f'Generations: {polish_generations_slider.value}, '
                      f'Mutation: {polish_mutation_slider.value:.3f}')
                print('Polishing...\n')

                progress_bar.layout.display = 'flex'
                progress_label.layout.display = 'block'
                progress_bar.value = 0

                weights = {
                    'cai': weight_sliders['cai'].value,
                    'gc_deviation': weight_sliders['gc'].value,
                    'folding_energy': weight_sliders['folding'].value,
                    'unwanted_motifs': weight_sliders['motifs'].value,
                    'repeats': weight_sliders['repeats'].value,
                    'cryptic_splice': weight_sliders['splice'].value,
                    'codon_pair_bias': weight_sliders['cps'].value,
                    'tai': weight_sliders['tai'].value,
                }

                try:
                    polished, fitness, metrics = genetic_algorithm(
                        initial_cds = repaired,
                        host = host,
                        is_eukaryote = is_eukaryote,
                        target_gc = get_target_gc(host),
                        pop_size = 20,
                        generations = polish_generations_slider.value,
                        mutation_rate = polish_mutation_slider.value,
                        weights = weights,
                        avoid_sequences = avoid_input.value,
                        verbose = True,
                        progress_callback = lambda g, t: update_progress(g, t),
                    )

                    progress_bar.layout.display = 'none'
                    progress_label.layout.display = 'none'
                    final_seq = polished

                    print(f'\nPolish Fitness: {fitness:.4f}')
                    print(f'CAI: {metrics["cai"]:.3f}')
                    print(f'GC: {metrics["gc_content"]:.1f}%')
                    if codon_pair_available_for(host):
                        print(f'Codon-pair score: {metrics["codon_pair_score"]:.3f}')
                    if tai_available_for(host):
                        print(f'tAI: {metrics["tai"]:.3f}')

                except Exception as e:
                    progress_bar.layout.display = 'none'
                    progress_label.layout.display = 'none'
                    print(f'\nGA polish failed: {str(e)}')
                    return

        # ---- Final output and analysis (all pipelines) ----
        if pipeline != 'preoptimization_only':
            print('\n' + '=' * 70)
            print('OPTIMIZATION COMPLETE')
            print('=' * 70)

            print('\nFinal Optimized Sequence:')
            display(Textarea(value = final_seq, layout = Layout(width = '600px', height = '400px')))

        final_cai = calculate_cai(final_seq, codon_table)
        final_gc = calculate_gc_content(final_seq)
        print(f'Final CAI: {final_cai:.3f}')
        print(f'Final GC: {final_gc:.1f}%')
        if codon_pair_available_for(host):
            final_cps = calculate_codon_pair_score(final_seq, host)
            print(f'Final codon-pair score: {final_cps:.3f}')
        if tai_available_for(host):
            final_tai = calculate_tai(final_seq, host)
            print(f'Final tAI: {final_tai:.3f}')

        # CHARMING-style harmonization quality readout: how close did we
        # stay to the input sequence's windowed profile in the target host?
        try:
            harm = harmonization_correlation(clean_seq, final_seq, host, measure = 'cai')
            r = harm['pearson_r']
            net_dev = harm['net_abs_dev']
            mad = harm['mean_abs_dev']
            r_str = f'{r:.3f}' if r == r else 'n/a'
            print(
                f'Harmonization diagnostics ({harm["measure"].upper()}, W=17): '
                f'r = {r_str}, net |dev| = {net_dev:.3f}, '
                f'mean |dev| = {mad:.3f} ({harm["n_windows"]} windows)'
            )
        except Exception as e:
            print(f'Harmonization diagnostics: failed ({e})')

        # ---- GCEH analysis: input vs final ----
        data_clean = gceh_anal('Input:', clean_seq)
        data_opt = gceh_anal('Optimized:', final_seq)
        print('\n' + 'CODON ANALYSIS')
        print('\nInput sequence:')
        print(data_clean.table_str)
        print('\nOptimized sequence:')
        print(data_opt.table_str)
        plot_codon_usage_compare(data_clean, data_opt, title = 'Codon usage: Input vs Optimized')
        plot_complexity_compare(data_clean, data_opt, comp_window = complexity_window.value, comp_step = complexity_step.value, comp_k = complexity_k.value, comp_alpha = complexity_alpha.value, comp_smooth = complexity_smooth.value, title = 'Complexity: Input vs Optimized')
        gc_window = len(final_seq) // 10
        plot_gc_sliding_compare(data_clean, data_opt, gc_window, step_nt = 1, title = 'Sliding GC%: Input vs Optimized')
        plot_gc3_compare(data_clean, data_opt, title = 'Cumulative GC3: Input vs Optimized')
        ten_percent = len(final_seq) // 10
        plot_gc3_sliding_compare(data_clean, data_opt, ten_percent, title = 'GC3 moving average: Input vs Optimized')

# Attach event handlers
backtranslate_button.on_click(on_backtranslate_click)
reset_button.on_click(on_reset_click)
optimize_button.on_click(on_optimize_click)

host_dropdown.observe(on_host_change, names = 'value')
codon_method_dropdown.observe(on_codon_method_change, names = 'value')
percentile_mode_dropdown.observe(on_percentile_mode_change, names = 'value')
pipeline_dropdown.observe(on_pipeline_change, names = 'value')
ga_polish_checkbox.observe(on_ga_polish_change, names = 'value')

for slider in weight_sliders.values():
    slider.observe(on_weight_change)

update_optional_weight_controls()
update_weight_labels()

# %% [markdown]
# ## 5. Display GUI

# %%
# Assemble and display the GUI
gui = VBox([
    HTML('<h2>mRNA Sequence Optimization Tool</h2>'),
    HTML('<hr>'),

    # Protein input section
    HTML('<h3>1. Protein Sequence (Optional)</h3>'),
    protein_input,
    HBox([backtranslate_button, protein_status]),

    HTML('<hr>'),

    # DNA input section
    HTML('<h3>2. Nucleotide Sequence for Optimization</h3>'),
    dna_input,
    dna_status,

    HTML('<hr>'),

    # Parameters section
    HTML('<h3>3. Optimization Parameters</h3>'),

    # Host
    VBox([
        HTML('<b>Host:</b>'),
        host_dropdown,
        HBox([HTML('<b>Host class:</b>'), host_class]),
    ]),

    # Codon method
    VBox([
        HTML('<b>Codon Optimization Method:</b>'),
        codon_method_dropdown,
        percentile_mode_dropdown,
        source_host_label,
        source_host_dropdown,
    ]),

    # Pipeline
    VBox([
        HTML('<b>Pipeline:</b>'),
        pipeline_dropdown,
    ]),

    # Avoid sequences (hidden for preoptimization_only)
    avoid_section,

    # GA settings / Repair settings
    ga_settings_box,
    repair_settings_box,

    # Complexity analysis (always visible)
    HTML('<h4>Complexity Analysis:</h4>'),
    VBox([
        complexity_window,
        complexity_step,
        complexity_k,
        complexity_smooth,
        complexity_alpha,
    ]),

    HTML('<hr>'),

    # Fitness weights (GA, or hybrid with polish)
    weights_section,

    HTML('<hr>'),

    # Run
    HTML('<h3>5. Run Optimization</h3>'),
    optimize_button,
    progress_bar,
    progress_label,

    HTML('<hr>'),

    # Output
    HTML('<h3>Results</h3>'),
    HTML('''
    <style>
    .output_area pre, .output_area {
        user-select: text !important;
        -webkit-user-select: text !important;
    }
    </style>
    '''),
    output_area,
])

display(gui)
